# %% [markdown]
# <a href="https://colab.research.google.com/github/Zhalil24/BreastMRI-CNN-Classification/blob/main/MobileNetV2_ipynbNewResult.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# 1. KÜTÜPHANELER
# ============================================================

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms, models

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

from sklearn.model_selection import StratifiedKFold

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
import shutil
import copy

from google.colab import drive
from IPython.display import display


# ============================================================
# 2. GPU / CUDA AYARI VE DRIVE BAĞLAMA
# ============================================================

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Sistem: {device} üzerinde çalışıyor.")

drive.mount('/content/drive')


# ============================================================
# 3. DATASET RAR DOSYASINI KOPYALAMA VE AÇMA
# ============================================================

rar_source_path = "/content/drive/MyDrive/data_set_zip/breast_mri_dataset.rar"
rar_target_path = "/content/breast_mri_dataset.rar"

shutil.copy(rar_source_path, rar_target_path)

# Aynı dosyalar varsa üzerine yazsın diye -o+ kullanıldı.
os.system(f'unrar x -o+ "{rar_target_path}" /content/')


# ============================================================
# 4. GENEL AYARLAR
# ============================================================

data_dir = "/content/breast_mri_dataset"

BATCH_SIZE = 32
NUM_EPOCHS = 10
NUM_CLASSES = 2


# ============================================================
# 5. ÇIKTI KLASÖRLERİ
# ============================================================

output_root = "/content/drive/MyDrive/breast_mri_mobilenetv2_outputs"
charts_dir = os.path.join(output_root, "charts")
tables_dir = os.path.join(output_root, "tables")

os.makedirs(output_root, exist_ok=True)
os.makedirs(charts_dir, exist_ok=True)
os.makedirs(tables_dir, exist_ok=True)

print(f"Çıktı klasörü: {output_root}")


# ============================================================
# 6. VERİ ARTIRMA VE ÖN İŞLEME
# ============================================================

mri_mean = [0.485, 0.456, 0.406]
mri_std = [0.229, 0.224, 0.225]

train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(10),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.3),
    transforms.RandomAffine(
        degrees=0,
        translate=(0.05, 0.05),
        scale=(0.95, 1.05)
    ),
    transforms.ColorJitter(brightness=0.15, contrast=0.15),
    transforms.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 2.0)),
    transforms.ToTensor(),
    transforms.Normalize(mri_mean, mri_std)
])

val_test_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mri_mean, mri_std)
])


# ============================================================
# 7. DATASETLERİN YÜKLENMESİ
# ============================================================

# Eğitim için augmentation'lı train dataset
full_dataset = datasets.ImageFolder(
    os.path.join(data_dir, "train"),
    transform=train_transforms
)

# Fold validation için augmentation'sız train dataset
full_dataset_eval = datasets.ImageFolder(
    os.path.join(data_dir, "train"),
    transform=val_test_transforms
)

test_dataset = datasets.ImageFolder(
    os.path.join(data_dir, "test"),
    transform=val_test_transforms
)

labels = np.array(full_dataset.targets)

class_names = full_dataset.classes
print("Sınıflar:", full_dataset.class_to_idx)

if len(class_names) == 2:
    display_class_names = ["Benign", "Malignant"]
else:
    display_class_names = class_names


# ============================================================
# 8. MOBILENETV2 MODELİNİ YAPILANDIRMA
# ============================================================

def build_mobilenet_model():
    model = models.mobilenet_v2(
        weights=models.MobileNet_V2_Weights.IMAGENET1K_V1
    )

    for i, child in enumerate(model.features):
        if i <= 6:
            for param in child.parameters():
                param.requires_grad = False
        else:
            for param in child.parameters():
                param.requires_grad = True

    num_ftrs = model.classifier[1].in_features

    model.classifier = nn.Sequential(
        nn.Dropout(p=0.2),
        nn.Linear(num_ftrs, NUM_CLASSES)
    )

    return model.to(device)


# ============================================================
# 9. DİFERANSİYEL ÖĞRENME ORANI
# ============================================================

def get_optimizer(model):
    optimizer = optim.Adam([
        {
            "params": model.features[7:10].parameters(),
            "lr": 1e-5
        },
        {
            "params": model.features[10:14].parameters(),
            "lr": 5e-5
        },
        {
            "params": model.features[14:19].parameters(),
            "lr": 1e-4
        },
        {
            "params": model.classifier.parameters(),
            "lr": 1e-3
        }
    ])

    return optimizer


criterion = nn.CrossEntropyLoss()


# ============================================================
# 10. MODEL AĞIRLIKLARINI GÜVENLİ KOPYALAMA
# ============================================================

def clone_state_dict_to_cpu(model):
    return {
        key: value.detach().cpu().clone()
        for key, value in model.state_dict().items()
    }


# ============================================================
# 11. TEK FOLD EĞİTİM FONKSİYONU
# ============================================================

def train_one_fold(fold_no, train_loader, val_loader, epochs=10):
    model = build_mobilenet_model()
    optimizer = get_optimizer(model)

    history = {
        "t_loss": [],
        "t_acc": [],
        "v_loss": [],
        "v_acc": []
    }

    best_epoch_val_acc = -1
    best_epoch_no = 1
    best_epoch_state = None

    for epoch in range(epochs):
        # -------------------------
        # Eğitim
        # -------------------------
        model.train()

        running_loss = 0.0
        running_correct = 0

        for inputs, labels_batch in train_loader:
            inputs = inputs.to(device)
            labels_batch = labels_batch.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            loss = criterion(outputs, labels_batch)

            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            running_correct += torch.sum(preds == labels_batch.data).item()

        train_loss = running_loss / len(train_loader.dataset)
        train_acc = running_correct / len(train_loader.dataset)

        # -------------------------
        # Validation
        # -------------------------
        model.eval()

        val_running_loss = 0.0
        val_running_correct = 0

        with torch.no_grad():
            for inputs, labels_batch in val_loader:
                inputs = inputs.to(device)
                labels_batch = labels_batch.to(device)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                loss = criterion(outputs, labels_batch)

                val_running_loss += loss.item() * inputs.size(0)
                val_running_correct += torch.sum(preds == labels_batch.data).item()

        val_loss = val_running_loss / len(val_loader.dataset)
        val_acc = val_running_correct / len(val_loader.dataset)

        print(
            f"Fold {fold_no} Ep {epoch+1}/{epochs}: "
            f"T_Loss: {train_loss:.4f} "
            f"T_Acc: {train_acc:.4f} | "
            f"V_Loss: {val_loss:.4f} "
            f"V_Acc: {val_acc:.4f}"
        )

        history["t_loss"].append(train_loss)
        history["t_acc"].append(train_acc)
        history["v_loss"].append(val_loss)
        history["v_acc"].append(val_acc)

        if val_acc > best_epoch_val_acc:
            best_epoch_val_acc = val_acc
            best_epoch_no = epoch + 1
            best_epoch_state = clone_state_dict_to_cpu(model)

    # Fold içindeki en iyi epoch ağırlıkları geri yükleniyor.
    if best_epoch_state is not None:
        model.load_state_dict(best_epoch_state)

    return model, history, best_epoch_no


# ============================================================
# 12. DETAYLI DEĞERLENDİRME FONKSİYONU
# ============================================================

def evaluate_model(model, loader):
    model.eval()

    all_preds = []
    all_labels = []
    all_probs = []

    with torch.no_grad():
        for inputs, labels_batch in loader:
            inputs = inputs.to(device)
            labels_batch = labels_batch.to(device)

            outputs = model(inputs)

            probs = torch.softmax(outputs, dim=1)[:, 1]
            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels_batch.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)
    all_probs = np.array(all_probs)

    metrics = {
        "accuracy": accuracy_score(all_labels, all_preds),
        "precision": precision_score(all_labels, all_preds, zero_division=0),
        "recall": recall_score(all_labels, all_preds, zero_division=0),
        "f1_score": f1_score(all_labels, all_preds, zero_division=0)
    }

    try:
        metrics["roc_auc"] = roc_auc_score(all_labels, all_probs)
    except ValueError:
        metrics["roc_auc"] = np.nan

    return metrics, all_labels, all_preds, all_probs


# ============================================================
# 13. GRAFİK FONKSİYONLARI
# ============================================================

def plot_accuracy(history, fold_no, save_path):
    epochs_range = range(1, len(history["t_acc"]) + 1)

    plt.figure(figsize=(9, 6))
    plt.plot(
        epochs_range,
        history["t_acc"],
        marker="o",
        label="Train Accuracy"
    )
    plt.plot(
        epochs_range,
        history["v_acc"],
        marker="o",
        label="Validation Accuracy"
    )

    plt.title(f"Fold {fold_no}/5 Accuracy Grafiği")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close()


def plot_loss(history, fold_no, save_path):
    epochs_range = range(1, len(history["t_loss"]) + 1)

    plt.figure(figsize=(9, 6))
    plt.plot(
        epochs_range,
        history["t_loss"],
        marker="o",
        label="Train Loss"
    )
    plt.plot(
        epochs_range,
        history["v_loss"],
        marker="o",
        label="Validation Loss"
    )

    plt.title(f"Fold {fold_no}/5 Loss Grafiği")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close()


def plot_confusion_matrix_graph(labels_data, preds_data, title, save_path):
    cm = confusion_matrix(labels_data, preds_data, labels=[0, 1])

    plt.figure(figsize=(7, 6))
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=display_class_names,
        yticklabels=display_class_names
    )

    plt.title(title)
    plt.ylabel("Gerçek")
    plt.xlabel("Tahmin")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close()


def plot_roc_curve_graph(labels_data, probs_data, title, save_path):
    plt.figure(figsize=(8, 6))

    try:
        fpr, tpr, _ = roc_curve(labels_data, probs_data)
        auc_value = roc_auc_score(labels_data, probs_data)

        plt.plot(
            fpr,
            tpr,
            lw=2,
            label=f"ROC Curve - AUC = {auc_value:.4f}"
        )

        plt.plot(
            [0, 1],
            [0, 1],
            linestyle="--",
            lw=2,
            label="Random Classifier"
        )

    except ValueError:
        plt.text(
            0.5,
            0.5,
            "ROC hesaplanamadı.\nValidation setinde tek sınıf olabilir.",
            ha="center",
            va="center"
        )

    plt.title(title)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close()


# ============================================================
# 14. 5-FOLD STRATIFIED CROSS-VALIDATION
# ============================================================

skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

fold_results = []
fold_summary_rows = []
epoch_history_rows = []
output_file_rows = []

# Her foldun kendi en iyi epoch modeli testte ayrı ayrı kullanılacak.
fold_model_states = []

print("\n--- 5-Fold Eğitim Başlıyor ---")

for fold_no, (train_idx, val_idx) in enumerate(
    skf.split(np.zeros(len(labels)), labels),
    start=1
):
    print(f"\n--- FOLD {fold_no} / 5 ---")

    train_sub = Subset(full_dataset, train_idx)

    # Validation tarafında augmentation kullanılmıyor.
    val_sub = Subset(full_dataset_eval, val_idx)

    train_loader = DataLoader(
        train_sub,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=2,
        pin_memory=torch.cuda.is_available()
    )

    val_loader = DataLoader(
        val_sub,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=2,
        pin_memory=torch.cuda.is_available()
    )

    model, history, best_epoch_no = train_one_fold(
        fold_no,
        train_loader,
        val_loader,
        epochs=NUM_EPOCHS
    )

    fold_results.append(history)

    # Fold validation metrikleri
    val_metrics, val_labels, val_preds, val_probs = evaluate_model(
        model,
        val_loader
    )

    print(f"\nFold {fold_no} Validation Performansı")
    print(f"Best Epoch: {best_epoch_no}")
    print(f"Accuracy:  {val_metrics['accuracy']:.4f}")
    print(f"Precision: {val_metrics['precision']:.4f}")
    print(f"Recall:    {val_metrics['recall']:.4f}")
    print(f"F1-Score:  {val_metrics['f1_score']:.4f}")
    print(f"ROC-AUC:   {val_metrics['roc_auc']:.4f}")

    accuracy_path = os.path.join(
        charts_dir,
        f"fold_{fold_no}_accuracy.png"
    )

    loss_path = os.path.join(
        charts_dir,
        f"fold_{fold_no}_loss.png"
    )

    cm_path = os.path.join(
        charts_dir,
        f"fold_{fold_no}_confusion_matrix.png"
    )

    roc_path = os.path.join(
        charts_dir,
        f"fold_{fold_no}_roc_curve.png"
    )

    # Her fold için 4 grafik
    plot_accuracy(
        history,
        fold_no,
        accuracy_path
    )

    plot_loss(
        history,
        fold_no,
        loss_path
    )

    plot_confusion_matrix_graph(
        val_labels,
        val_preds,
        title=f"Fold {fold_no}/5 Validation Confusion Matrix",
        save_path=cm_path
    )

    plot_roc_curve_graph(
        val_labels,
        val_probs,
        title=f"Fold {fold_no}/5 Validation ROC-AUC Grafiği",
        save_path=roc_path
    )

    fold_summary_rows.append({
        "Fold": fold_no,
        "Best_Epoch": best_epoch_no,
        "Validation_Accuracy": val_metrics["accuracy"],
        "Validation_Precision": val_metrics["precision"],
        "Validation_Recall": val_metrics["recall"],
        "Validation_F1_Score": val_metrics["f1_score"],
        "Validation_ROC_AUC": val_metrics["roc_auc"],
        "Accuracy_Graph": accuracy_path,
        "Loss_Graph": loss_path,
        "Confusion_Matrix_Graph": cm_path,
        "ROC_Curve_Graph": roc_path
    })

    output_file_rows.extend([
        {
            "Output_Type": "Fold Accuracy Graph",
            "Fold": fold_no,
            "File_Path": accuracy_path
        },
        {
            "Output_Type": "Fold Loss Graph",
            "Fold": fold_no,
            "File_Path": loss_path
        },
        {
            "Output_Type": "Fold Confusion Matrix Graph",
            "Fold": fold_no,
            "File_Path": cm_path
        },
        {
            "Output_Type": "Fold ROC Curve Graph",
            "Fold": fold_no,
            "File_Path": roc_path
        }
    ])

    # Her foldun kendi en iyi epoch modeli test için saklanıyor.
    fold_model_states.append({
        "Fold": fold_no,
        "Best_Epoch": best_epoch_no,
        "Model_State": clone_state_dict_to_cpu(model)
    })

print("\n--- Tüm Foldlar Başarıyla Tamamlandı ---")


# ============================================================
# 15. FOLD TABLOLARI
# ============================================================

for history_index, history_item in enumerate(fold_results, start=1):
    for epoch_index in range(len(history_item["t_acc"])):
        epoch_history_rows.append({
            "Fold": history_index,
            "Epoch": epoch_index + 1,
            "Train_Loss": history_item["t_loss"][epoch_index],
            "Train_Accuracy": history_item["t_acc"][epoch_index],
            "Validation_Loss": history_item["v_loss"][epoch_index],
            "Validation_Accuracy": history_item["v_acc"][epoch_index]
        })

fold_summary_df = pd.DataFrame(fold_summary_rows)
epoch_history_df = pd.DataFrame(epoch_history_rows)

print("\n--- FOLD ÖZET TABLOSU ---")
display(fold_summary_df)

print("\n--- EPOCH GEÇMİŞ TABLOSU ---")
display(epoch_history_df)


# ============================================================
# 16. HER FOLD MODELİNİ TEST SETİNDE DEĞERLENDİRME
# ============================================================

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    pin_memory=torch.cuda.is_available()
)

final_test_rows = []

print("\n" + "=" * 40)
print("HER FOLD İÇİN TEST SETİ PERFORMANSI")
print("=" * 40)

for fold_item in fold_model_states:
    fold_no = fold_item["Fold"]
    best_epoch_no = fold_item["Best_Epoch"]

    test_model = build_mobilenet_model()
    test_model.load_state_dict(fold_item["Model_State"])
    test_model.to(device)

    test_metrics, all_labels, all_preds, all_probs = evaluate_model(
        test_model,
        test_loader
    )

    print(f"\nFold {fold_no} Model Test Performansı")
    print(f"Best Epoch: {best_epoch_no}")
    print(f"Accuracy:  {test_metrics['accuracy']:.4f}")
    print(f"Precision: {test_metrics['precision']:.4f}")
    print(f"Recall:    {test_metrics['recall']:.4f}")
    print(f"F1-Score:  {test_metrics['f1_score']:.4f}")
    print(f"ROC-AUC:   {test_metrics['roc_auc']:.4f}")

    final_test_rows.append({
        "Fold": fold_no,
        "Final_Model": f"Fold {fold_no} Model",
        "Best_Epoch": best_epoch_no,
        "Test_Accuracy": test_metrics["accuracy"],
        "Test_Precision": test_metrics["precision"],
        "Test_Recall": test_metrics["recall"],
        "Test_F1_Score": test_metrics["f1_score"],
        "Test_ROC_AUC": test_metrics["roc_auc"]
    })

    fold_test_cm_path = os.path.join(
        charts_dir,
        f"fold_{fold_no}_test_confusion_matrix.png"
    )

    plot_confusion_matrix_graph(
        all_labels,
        all_preds,
        title=f"Fold {fold_no}/5 Test Confusion Matrix",
        save_path=fold_test_cm_path
    )

    fold_test_roc_path = os.path.join(
        charts_dir,
        f"fold_{fold_no}_test_roc_curve.png"
    )

    plot_roc_curve_graph(
        all_labels,
        all_probs,
        title=f"Fold {fold_no}/5 Test ROC-AUC Grafiği",
        save_path=fold_test_roc_path
    )

    output_file_rows.extend([
        {
            "Output_Type": "Fold Test Confusion Matrix Graph",
            "Fold": fold_no,
            "File_Path": fold_test_cm_path
        },
        {
            "Output_Type": "Fold Test ROC Curve Graph",
            "Fold": fold_no,
            "File_Path": fold_test_roc_path
        }
    ])

final_test_df = pd.DataFrame(final_test_rows)

print("\n--- HER FOLD TEST TABLOSU ---")
display(final_test_df)


# ============================================================
# 17. MEVCUT ORTALAMA ACCURACY GRAFİĞİ
# ============================================================
# Eski kodda olan grafik korunuyor.

num_epochs = len(fold_results[0]["t_acc"])
epochs_range = range(1, num_epochs + 1)

all_train_accs = np.array([
    res["t_acc"]
    for res in fold_results
])

all_val_accs = np.array([
    res["v_acc"]
    for res in fold_results
])

all_train_losses = np.array([
    res["t_loss"]
    for res in fold_results
])

all_val_losses = np.array([
    res["v_loss"]
    for res in fold_results
])

mean_train_acc = np.mean(all_train_accs, axis=0)
mean_val_acc = np.mean(all_val_accs, axis=0)

mean_train_loss = np.mean(all_train_losses, axis=0)
mean_val_loss = np.mean(all_val_losses, axis=0)

average_accuracy_path = os.path.join(
    charts_dir,
    "average_training_vs_validation_accuracy.png"
)

plt.figure(figsize=(9, 6))
plt.plot(
    epochs_range,
    mean_train_acc,
    label="Average Train Acc",
    marker="o"
)
plt.plot(
    epochs_range,
    mean_val_acc,
    label="Average Val Acc",
    marker="s"
)

plt.title("Training vs Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
plt.savefig(average_accuracy_path, dpi=300, bbox_inches="tight")
plt.show()
plt.close()

output_file_rows.append({
    "Output_Type": "Average Accuracy Graph",
    "Fold": "All",
    "File_Path": average_accuracy_path
})


# ============================================================
# 18. TÜM SONUÇLARI EXCEL DOSYASINA KAYDETME
# ============================================================

output_files_df = pd.DataFrame(output_file_rows)

excel_path = os.path.join(
    tables_dir,
    "mobilenetv2_breast_mri_model_results.xlsx"
)

with pd.ExcelWriter(excel_path, engine="openpyxl") as writer:
    fold_summary_df.to_excel(
        writer,
        sheet_name="Fold_Summary",
        index=False
    )

    epoch_history_df.to_excel(
        writer,
        sheet_name="Epoch_History",
        index=False
    )

    final_test_df.to_excel(
        writer,
        sheet_name="Final_Test",
        index=False
    )

    output_files_df.to_excel(
        writer,
        sheet_name="Output_Files",
        index=False
    )

print("\n--- KAYIT İŞLEMİ TAMAMLANDI ---")
print(f"Grafikler klasörü: {charts_dir}")
print(f"Excel dosyası: {excel_path}")

print("\nÜretilen çıktı dosyaları:")
display(output_files_df)
# Out:
# Sistem: cuda:0 üzerinde çalışıyor.
# Mounted at /content/drive
# Çıktı klasörü: /content/drive/MyDrive/breast_mri_mobilenetv2_outputs
# Sınıflar: {'Benign': 0, 'Malignant': 1}
#
# --- 5-Fold Eğitim Başlıyor ---
#
# --- FOLD 1 / 5 ---
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 151MB/s]
# Fold 1 Ep 1/10: T_Loss: 0.4670 T_Acc: 0.7588 | V_Loss: 0.2674 V_Acc: 0.8770
# Fold 1 Ep 2/10: T_Loss: 0.2982 T_Acc: 0.8619 | V_Loss: 0.1984 V_Acc: 0.9156
# Fold 1 Ep 3/10: T_Loss: 0.2330 T_Acc: 0.8955 | V_Loss: 0.1704 V_Acc: 0.9263
# Fold 1 Ep 4/10: T_Loss: 0.1808 T_Acc: 0.9211 | V_Loss: 0.1163 V_Acc: 0.9498
# Fold 1 Ep 5/10: T_Loss: 0.1595 T_Acc: 0.9308 | V_Loss: 0.1044 V_Acc: 0.9542
# Fold 1 Ep 6/10: T_Loss: 0.1434 T_Acc: 0.9415 | V_Loss: 0.1398 V_Acc: 0.9388
# Fold 1 Ep 7/10: T_Loss: 0.1184 T_Acc: 0.9536 | V_Loss: 0.0979 V_Acc: 0.9522
# Fold 1 Ep 8/10: T_Loss: 0.1077 T_Acc: 0.9579 | V_Loss: 0.0800 V_Acc: 0.9661
# Fold 1 Ep 9/10: T_Loss: 0.1052 T_Acc: 0.9572 | V_Loss: 0.1233 V_Acc: 0.9486
# Fold 1 Ep 10/10: T_Loss: 0.0871 T_Acc: 0.9654 | V_Loss: 0.0603 V_Acc: 0.9762
#
# Fold 1 Validation Performansı
# Best Epoch: 10
# Accuracy:  0.9762
# Precision: 0.9902
# Recall:    0.9620
# F1-Score:  0.9759
# ROC-AUC:   0.9983
# --- FOLD 2 / 5 ---
# Fold 2 Ep 1/10: T_Loss: 0.4632 T_Acc: 0.7635 | V_Loss: 0.3113 V_Acc: 0.8502
# Fold 2 Ep 2/10: T_Loss: 0.3094 T_Acc: 0.8601 | V_Loss: 0.1978 V_Acc: 0.9079
# Fold 2 Ep 3/10: T_Loss: 0.2279 T_Acc: 0.8985 | V_Loss: 0.1526 V_Acc: 0.9367
# Fold 2 Ep 4/10: T_Loss: 0.1837 T_Acc: 0.9219 | V_Loss: 0.1430 V_Acc: 0.9412
# Fold 2 Ep 5/10: T_Loss: 0.1560 T_Acc: 0.9348 | V_Loss: 0.0955 V_Acc: 0.9599
# Fold 2 Ep 6/10: T_Loss: 0.1386 T_Acc: 0.9429 | V_Loss: 0.0867 V_Acc: 0.9646
# Fold 2 Ep 7/10: T_Loss: 0.1205 T_Acc: 0.9507 | V_Loss: 0.1067 V_Acc: 0.9599
# Fold 2 Ep 8/10: T_Loss: 0.1192 T_Acc: 0.9508 | V_Loss: 0.0685 V_Acc: 0.9750
# Fold 2 Ep 9/10: T_Loss: 0.0894 T_Acc: 0.9636 | V_Loss: 0.0840 V_Acc: 0.9688
# Fold 2 Ep 10/10: T_Loss: 0.0933 T_Acc: 0.9645 | V_Loss: 0.0694 V_Acc: 0.9724
#
# Fold 2 Validation Performansı
# Best Epoch: 8
# Accuracy:  0.9750
# Precision: 0.9842
# Recall:    0.9655
# F1-Score:  0.9748
# ROC-AUC:   0.9974
# --- FOLD 3 / 5 ---
# Fold 3 Ep 1/10: T_Loss: 0.4793 T_Acc: 0.7526 | V_Loss: 0.2663 V_Acc: 0.8731
# Fold 3 Ep 2/10: T_Loss: 0.3006 T_Acc: 0.8641 | V_Loss: 0.2106 V_Acc: 0.9031
# Fold 3 Ep 3/10: T_Loss: 0.2292 T_Acc: 0.8983 | V_Loss: 0.1269 V_Acc: 0.9465
# Fold 3 Ep 4/10: T_Loss: 0.1757 T_Acc: 0.9208 | V_Loss: 0.1384 V_Acc: 0.9355
# Fold 3 Ep 5/10: T_Loss: 0.1619 T_Acc: 0.9291 | V_Loss: 0.1008 V_Acc: 0.9551
# Fold 3 Ep 6/10: T_Loss: 0.1413 T_Acc: 0.9412 | V_Loss: 0.0917 V_Acc: 0.9608
# Fold 3 Ep 7/10: T_Loss: 0.1230 T_Acc: 0.9491 | V_Loss: 0.0744 V_Acc: 0.9676
# Fold 3 Ep 8/10: T_Loss: 0.1106 T_Acc: 0.9555 | V_Loss: 0.0762 V_Acc: 0.9667
# Fold 3 Ep 9/10: T_Loss: 0.1085 T_Acc: 0.9577 | V_Loss: 0.0730 V_Acc: 0.9712
# Fold 3 Ep 10/10: T_Loss: 0.0875 T_Acc: 0.9643 | V_Loss: 0.0596 V_Acc: 0.9771
#
# Fold 3 Validation Performansı
# Best Epoch: 10
# Accuracy:  0.9771
# Precision: 0.9780
# Recall:    0.9762
# F1-Score:  0.9771
# ROC-AUC:   0.9979
# --- FOLD 4 / 5 ---
# Fold 4 Ep 1/10: T_Loss: 0.4729 T_Acc: 0.7596 | V_Loss: 0.2756 V_Acc: 0.8746
# Fold 4 Ep 2/10: T_Loss: 0.2952 T_Acc: 0.8628 | V_Loss: 0.1686 V_Acc: 0.9287
# Fold 4 Ep 3/10: T_Loss: 0.2272 T_Acc: 0.8982 | V_Loss: 0.1421 V_Acc: 0.9382
# Fold 4 Ep 4/10: T_Loss: 0.1870 T_Acc: 0.9201 | V_Loss: 0.1290 V_Acc: 0.9486
# Fold 4 Ep 5/10: T_Loss: 0.1557 T_Acc: 0.9357 | V_Loss: 0.1059 V_Acc: 0.9504
# Fold 4 Ep 6/10: T_Loss: 0.1351 T_Acc: 0.9451 | V_Loss: 0.0907 V_Acc: 0.9637
# Fold 4 Ep 7/10: T_Loss: 0.1159 T_Acc: 0.9516 | V_Loss: 0.0775 V_Acc: 0.9670
# Fold 4 Ep 8/10: T_Loss: 0.1057 T_Acc: 0.9551 | V_Loss: 0.0669 V_Acc: 0.9715
# Fold 4 Ep 9/10: T_Loss: 0.0962 T_Acc: 0.9605 | V_Loss: 0.0936 V_Acc: 0.9634
# Fold 4 Ep 10/10: T_Loss: 0.0889 T_Acc: 0.9663 | V_Loss: 0.0529 V_Acc: 0.9804
#
# Fold 4 Validation Performansı
# Best Epoch: 10
# Accuracy:  0.9804
# Precision: 0.9885
# Recall:    0.9721
# F1-Score:  0.9802
# ROC-AUC:   0.9984
# --- FOLD 5 / 5 ---
# Fold 5 Ep 1/10: T_Loss: 0.4719 T_Acc: 0.7576 | V_Loss: 0.3655 V_Acc: 0.8267
# Fold 5 Ep 2/10: T_Loss: 0.2982 T_Acc: 0.8638 | V_Loss: 0.1764 V_Acc: 0.9245
# Fold 5 Ep 3/10: T_Loss: 0.2237 T_Acc: 0.9013 | V_Loss: 0.1425 V_Acc: 0.9429
# Fold 5 Ep 4/10: T_Loss: 0.1781 T_Acc: 0.9227 | V_Loss: 0.1224 V_Acc: 0.9492
# Fold 5 Ep 5/10: T_Loss: 0.1475 T_Acc: 0.9380 | V_Loss: 0.0909 V_Acc: 0.9620
# Fold 5 Ep 6/10: T_Loss: 0.1301 T_Acc: 0.9475 | V_Loss: 0.1218 V_Acc: 0.9459
# Fold 5 Ep 7/10: T_Loss: 0.1205 T_Acc: 0.9510 | V_Loss: 0.0719 V_Acc: 0.9691
# Fold 5 Ep 8/10: T_Loss: 0.1163 T_Acc: 0.9543 | V_Loss: 0.0809 V_Acc: 0.9652
# Fold 5 Ep 9/10: T_Loss: 0.0933 T_Acc: 0.9615 | V_Loss: 0.0596 V_Acc: 0.9771
# Fold 5 Ep 10/10: T_Loss: 0.0866 T_Acc: 0.9662 | V_Loss: 0.0589 V_Acc: 0.9780
#
# Fold 5 Validation Performansı
# Best Epoch: 10
# Accuracy:  0.9780
# Precision: 0.9746
# Recall:    0.9816
# F1-Score:  0.9781
# ROC-AUC:   0.9979
# --- Tüm Foldlar Başarıyla Tamamlandı ---
#
# --- FOLD ÖZET TABLOSU ---
#    Fold  Best_Epoch  Validation_Accuracy  Validation_Precision  \
# 0     1          10             0.976233              0.990214
# 1     2           8             0.975037              0.984242
# 2     3          10             0.977117              0.977963
# 3     4          10             0.980386              0.988520
# 4     5          10             0.978009              0.974631
#
#    Validation_Recall  Validation_F1_Score  Validation_ROC_AUC  \
# 0           0.961973             0.975889            0.998266
# 1           0.965517             0.974790            0.997398
# 2           0.976219             0.977090            0.997929
# 3           0.972074             0.980228            0.998433
# 4           0.981581             0.978094            0.997905
#
#                                       Accuracy_Graph  \
# 0  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 1  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 2  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 3  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 4  /content/drive/MyDrive/breast_mri_mobilenetv2_...
#
#                                           Loss_Graph  \
# 0  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 1  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 2  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 3  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 4  /content/drive/MyDrive/breast_mri_mobilenetv2_...
#
#                               Confusion_Matrix_Graph  \
# 0  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 1  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 2  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 3  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 4  /content/drive/MyDrive/breast_mri_mobilenetv2_...
#
#                                      ROC_Curve_Graph
# 0  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 1  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 2  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 3  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 4  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# --- EPOCH GEÇMİŞ TABLOSU ---
#     Fold  Epoch  Train_Loss  Train_Accuracy  Validation_Loss  \
# 0      1      1    0.466974        0.758841         0.267353
# 1      1      2    0.298249        0.861887         0.198370
# 2      1      3    0.233009        0.895468         0.170376
# 3      1      4    0.180792        0.921100         0.116305
# 4      1      5    0.159451        0.930832         0.104434
# 5      1      6    0.143422        0.941456         0.139837
# 6      1      7    0.118434        0.953566         0.097864
# 7      1      8    0.107656        0.957875         0.079951
# 8      1      9    0.105161        0.957207         0.123255
# 9      1     10    0.087104        0.965379         0.060347
# 10     2      1    0.463167        0.763539         0.311298
# 11     2      2    0.309384        0.860114         0.197776
# 12     2      3    0.227854        0.898522         0.152620
# 13     2      4    0.183685        0.921923         0.143044
# 14     2      5    0.155963        0.934775         0.095489
# 15     2      6    0.138644        0.942872         0.086697
# 16     2      7    0.120469        0.950672         0.106652
# 17     2      8    0.119175        0.950821         0.068506
# 18     2      9    0.089433        0.963599         0.084030
# 19     2     10    0.093334        0.964490         0.069410
# 20     3      1    0.479266        0.752619         0.266276
# 21     3      2    0.300594        0.864052         0.210622
# 22     3      3    0.229229        0.898299         0.126918
# 23     3      4    0.175722        0.920808         0.138428
# 24     3      5    0.161891        0.929129         0.100780
# 25     3      6    0.141344        0.941163         0.091686
# 26     3      7    0.122996        0.949112         0.074444
# 27     3      8    0.110650        0.955501         0.076169
# 28     3      9    0.108539        0.957655         0.073001
# 29     3     10    0.087476        0.964267         0.059612
# 30     4      1    0.472924        0.759602         0.275628
# 31     4      2    0.295181        0.862789         0.168649
# 32     4      3    0.227231        0.898225         0.142082
# 33     4      4    0.187040        0.920065         0.129029
# 34     4      5    0.155721        0.935666         0.105903
# 35     4      6    0.135105        0.945101         0.090733
# 36     4      7    0.115907        0.951638         0.077522
# 37     4      8    0.105732        0.955055         0.066915
# 38     4      9    0.096150        0.960478         0.093648
# 39     4     10    0.088918        0.966347         0.052921
# 40     5      1    0.471925        0.757596         0.365466
# 41     5      2    0.298193        0.863755         0.176437
# 42     5      3    0.223678        0.901270         0.142477
# 43     5      4    0.178051        0.922740         0.122421
# 44     5      5    0.147506        0.938043         0.090910
# 45     5      6    0.130081        0.947478         0.121843
# 46     5      7    0.120507        0.951044         0.071865
# 47     5      8    0.116268        0.954312         0.080925
# 48     5      9    0.093271        0.961518         0.059596
# 49     5     10    0.086622        0.966199         0.058876
#
#     Validation_Accuracy
# 0              0.877005
# 1              0.915627
# 2              0.926322
# 3              0.949792
# 4              0.954248
# 5              0.938800
# 6              0.952169
# 7              0.966132
# 8              0.948604
# 9              0.976233
# 10             0.850223
# 11             0.907875
# 12             0.936701
# 13             0.941159
# 14             0.959881
# 15             0.964636
# 16             0.959881
# 17             0.975037
# 18             0.968796
# 19             0.972363
# 20             0.873105
# 21             0.903120
# 22             0.946508
# 23             0.935513
# 24             0.955126
# 25             0.960773
# 26             0.967608
# 27             0.966716
# 28             0.971174
# 29             0.977117
# 30             0.874591
# 31             0.928678
# 32             0.938187
# 33             0.948588
# 34             0.950371
# 35             0.963744
# 36             0.967013
# 37             0.971471
# 38             0.963447
# 39             0.980386
# 40             0.826746
# 41             0.924517
# 42             0.942942
# 43             0.949183
# 44             0.961961
# 45             0.945914
# 46             0.969094
# 47             0.965230
# 48             0.977117
# 49             0.978009
# ========================================
# HER FOLD İÇİN TEST SETİ PERFORMANSI
# ========================================
#
# Fold 1 Model Test Performansı
# Best Epoch: 10
# Accuracy:  0.9731
# Precision: 0.9942
# Recall:    0.9517
# F1-Score:  0.9725
# ROC-AUC:   0.9984
# Fold 2 Model Test Performansı
# Best Epoch: 8
# Accuracy:  0.9739
# Precision: 0.9852
# Recall:    0.9623
# F1-Score:  0.9736
# ROC-AUC:   0.9976
# Fold 3 Model Test Performansı
# Best Epoch: 10
# Accuracy:  0.9806
# Precision: 0.9816
# Recall:    0.9795
# F1-Score:  0.9806
# ROC-AUC:   0.9986
# Fold 4 Model Test Performansı
# Best Epoch: 10
# Accuracy:  0.9822
# Precision: 0.9904
# Recall:    0.9739
# F1-Score:  0.9821
# ROC-AUC:   0.9989
# Fold 5 Model Test Performansı
# Best Epoch: 10
# Accuracy:  0.9814
# Precision: 0.9774
# Recall:    0.9856
# F1-Score:  0.9815
# ROC-AUC:   0.9985
# --- HER FOLD TEST TABLOSU ---
#    Fold   Final_Model  Best_Epoch  Test_Accuracy  Test_Precision  Test_Recall  \
# 0     1  Fold 1 Model          10       0.973085        0.994203     0.951720
# 1     2  Fold 2 Model           8       0.973918        0.985227     0.962264
# 2     3  Fold 3 Model          10       0.980577        0.981646     0.979467
# 3     4  Fold 4 Model          10       0.982242        0.990406     0.973918
# 4     5  Fold 5 Model          10       0.981410        0.977435     0.985572
#
#    Test_F1_Score  Test_ROC_AUC
# 0       0.972498      0.998358
# 1       0.973610      0.997575
# 2       0.980556      0.998574
# 3       0.982093      0.998886
# 4       0.981487      0.998520
# --- KAYIT İŞLEMİ TAMAMLANDI ---
# Grafikler klasörü: /content/drive/MyDrive/breast_mri_mobilenetv2_outputs/charts
# Excel dosyası: /content/drive/MyDrive/breast_mri_mobilenetv2_outputs/tables/mobilenetv2_breast_mri_model_results.xlsx
#
# Üretilen çıktı dosyaları:
#                          Output_Type Fold  \
# 0                Fold Accuracy Graph    1
# 1                    Fold Loss Graph    1
# 2        Fold Confusion Matrix Graph    1
# 3               Fold ROC Curve Graph    1
# 4                Fold Accuracy Graph    2
# 5                    Fold Loss Graph    2
# 6        Fold Confusion Matrix Graph    2
# 7               Fold ROC Curve Graph    2
# 8                Fold Accuracy Graph    3
# 9                    Fold Loss Graph    3
# 10       Fold Confusion Matrix Graph    3
# 11              Fold ROC Curve Graph    3
# 12               Fold Accuracy Graph    4
# 13                   Fold Loss Graph    4
# 14       Fold Confusion Matrix Graph    4
# 15              Fold ROC Curve Graph    4
# 16               Fold Accuracy Graph    5
# 17                   Fold Loss Graph    5
# 18       Fold Confusion Matrix Graph    5
# 19              Fold ROC Curve Graph    5
# 20  Fold Test Confusion Matrix Graph    1
# 21         Fold Test ROC Curve Graph    1
# 22  Fold Test Confusion Matrix Graph    2
# 23         Fold Test ROC Curve Graph    2
# 24  Fold Test Confusion Matrix Graph    3
# 25         Fold Test ROC Curve Graph    3
# 26  Fold Test Confusion Matrix Graph    4
# 27         Fold Test ROC Curve Graph    4
# 28  Fold Test Confusion Matrix Graph    5
# 29         Fold Test ROC Curve Graph    5
# 30            Average Accuracy Graph  All
#
#                                             File_Path
# 0   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 1   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 2   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 3   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 4   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 5   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 6   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 7   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 8   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 9   /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 10  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 11  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 12  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 13  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 14  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 15  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 16  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 17  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 18  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 19  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 20  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 21  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 22  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 23  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 24  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 25  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 26  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 27  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 28  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 29  /content/drive/MyDrive/breast_mri_mobilenetv2_...
# 30  /content/drive/MyDrive/breast_mri_mobilenetv2_...
